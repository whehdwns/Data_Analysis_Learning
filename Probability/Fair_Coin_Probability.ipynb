# %%
import random 
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import math
warnings.filterwarnings('ignore')

# %%
def coin_random(n):
    count=0
    for i in range(n):
        rand=random.randint(0,1)
        if rand==1:
            count+=1
        prob=count/n
    return prob

# %%
Y=[]
number=1000
for i in range(1,number+1):
    Y.append(coin_random(i))
X=list(range(1, number+1))

# %%
probability=np.array(X)
trials=np.array(Y)
dataset=pd.DataFrame({'Probability':Y, 'Trials':X}, columns=['Probability','Trials'])
dataset
# Out:
#      Probability  Trials
# 0       0.000000       1
# 1       0.500000       2
# 2       0.333333       3
# 3       0.250000       4
# 4       0.600000       5
# ..           ...     ...
# 995     0.517068     996
# 996     0.488465     997
# 997     0.491984     998
# 998     0.504505     999
# 999     0.482000    1000
#
# [1000 rows x 2 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
sns.lmplot(data=dataset, x='Trials', y='Probability')

# %%
X=dataset[['Trials']]
Y=dataset[['Probability']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(normalize=True)
model.fit(X_train,Y_train)
# Out:
# LinearRegression(normalize=True)

# %%
model.intercept_
# Out:
# array([0.49019498])

# %%
model.coef_
# Out:
# array([[1.37290442e-05]])

# %%
pred = model.predict(X_test)

# %%
model.score(X_test,Y_test)
# Out:
# -0.04115573567460751

# %%
plt.scatter(X_test, Y_test)
plt.plot(X_test, pred, color = 'g')

# %%
test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)

# %%
print_evaluate(Y_train,train_pred)
# Out:
# MAE: 0.024470612586257375
# MSE: 0.0016855805922553688
# RMSE: 0.04105582287879965
# R2 Square 0.00938823585456372

# %%
def error_rate(a,b):
    return (abs(b-a)/abs(a))*100

# %%
error_rate(0.5,0.50125506)
# Out:
# 0.2510119999999949

# %% [markdown]
# - Probability of Fair Coin generated by linear regression is 0.50125506
# - Calculated probability of Fair coin is 0.5
# - There are 0.25 % error between experimental and actual
